# %% [markdown]
# Yizhi Jiao
# PHYS 29
# Homework 8

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import interpolate

# %% [markdown]
# 1(a)

# %%
data=np.loadtxt('HW8data.txt')
x=data[:,0]
f=data[:,1]

# %% [markdown]
# Assign data in the HW8data.txt file to the variable data.
# Assign all items in the first column of data as an array to x.
# Assign all items in the second column of data as an array to f.
# The variable data is a 2D array.

# %% [markdown]
# 1(b)

# %%
plt.plot(x, f, linestyle=' ', marker='.')
plt.title('dot plot')
plt.xlabel('x')
plt.ylabel('f')
# Out:
# Text(0, 0.5, 'f')

# %% [markdown]
# 1(c)

# %%
xnew = np.linspace(-10,5)
plt.plot(x, f, linestyle=' ', marker='.')
plt.plot(xnew, interpolate.interp1d(x, f)(xnew), color='r', label='linear')
plt.title('linear interpolation')
plt.legend()
plt.xlabel('x')
plt.ylabel('f')
# Out:
# Text(0, 0.5, 'f')

# %% [markdown]
# 1(d)

# %%
plt.plot(x, f, linestyle=' ', marker='.')
plt.plot(xnew, interpolate.interp1d(x, f, kind='cubic')(xnew), color='g', label='cubic')
plt.title('cubic interpolation')
plt.legend()
plt.xlabel('x')
plt.ylabel('f')
# Out:
# Text(0, 0.5, 'f')

# %% [markdown]
# Problem 2

# %%
x = np.linspace(-12, 12, 500)
y = np.linspace(-12, 12, 500)
x_grid, y_grid= np.meshgrid(x, y)
i_0 = 1
r = np.array([0.5, 1, 2])
i = i_0*np.sinc(x_grid/np.pi)**2*np.sinc(r[0]*y_grid/np.pi)**2
plt.imshow(i, vmax='0.005', extent=[x[0],x[-1],y[0],y[-1]])
plt.title('r = 0.5')
plt.colorbar(label="Intensity")
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
i = i_0*np.sinc(x_grid/np.pi)**2*np.sinc(r[1]*y_grid/np.pi)**2
plt.imshow(i,vmax='0.005', extent=[x[0],x[-1],y[0],y[-1]])
plt.title('r = 1')
plt.colorbar(label="Intensity")
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
i = i_0*np.sinc(x_grid/np.pi)**2*np.sinc(r[2]*y_grid/np.pi)**2
plt.imshow(i,vmax='0.005', extent=[x[0],x[-1],y[0],y[-1]])
plt.title('r = 2')
plt.colorbar(label="Intensity")
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# For fixed horizontal width, the intensity increases then decreases as the vertical width increases.

# %% [markdown]
# Problem 3

# %%
x = np.linspace(0, 1, 1000)
y = np.linspace(0, 1, 1000)
x_grid, y_grid = np.meshgrid(x, y)
t = 0
for n in range(1, 100, 2):
    t += 400 / (n*np.pi*np.sinh(n*np.pi)) * np.sinh(n*np.pi*y_grid) * np.sin(n*np.pi*x_grid)
plot = plt.contour(x_grid, y_grid, t, 11)
plt.clabel(plot, inline=1, fontsize=10)
# Out:
# <a list of 10 text.Text objects>
