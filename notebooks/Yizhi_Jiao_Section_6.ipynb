# %%
import sympy as sym
import numpy as np
import scipy as sci
import matplotlib.pyplot as plt

# %%
l=sym.symbols('$\\lambda$')
a=sym.symbols('a')
t=sym.symbols('$\\theta$')
alpha = sym.symbols('$\\alpha$')
i=sym.symbols('$I_0$')

# %%
def normal_i(alpha):
   return np.sinc(alpha/np.pi)**2

# %%
x = np.linspace(-10,10,1000)
y = normal_i(np.linspace(-10,10,1000))
plt.title('lalala')
plt.plot(x,y)
plt.show()

# %%
# Out:
# Text(1, 1, '$\\alpha$')
