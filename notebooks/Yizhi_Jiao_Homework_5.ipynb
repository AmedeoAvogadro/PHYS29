# %% [markdown]
# Yizhi Jiao
# PHYS 29
# Homework 5

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Problem 1

# %%
def x(t, a, gamma, omega_0, phi):
    omega=(omega_0**2-gamma**2/4)**0.5
    return a*np.e**(-gamma*t/2)*np.cos(omega*t+phi)
time = np.linspace(1,1000,1000)/100
displacement_1 = x(time,1,1,1,-np.pi/2)
displacement_2 = x(time,1,0.5,1,-np.pi/2)
displacement_3 = x(time,1,1.5,1,-np.pi/2)
plt.title("Damped Oscillator with Different $\\gamma$ (A=1, $\\omega_0$=1, $\\phi$=1)")
plt.plot(time, displacement_1, color ="r", label="$\\gamma$ = 1")
plt.plot(time, displacement_2, color ="g", label="$\\gamma$ = 0.5")
plt.plot(time, displacement_3, color ="b", label="$\\gamma$ = 1.5")
leg = plt.legend(loc='upper center')
plt.ylabel('displacement / m')
plt.xlabel('time / s')
plt.show()

# %% [markdown]
# Problem 2(a)

# %% [markdown]
# Use Mathematica to find the first term of Taylor series $F_\nu$ at $x = 0$
# $$F_\nu = \frac{2\pi k_B T \nu^2}{c^2}$$
# so the power law of this relationship is $F_\nu \propto \nu^2$

# %%
def F_nu(T, nu):
    k_B=1.380649e-23
    c=299792458
    return 2*np.pi*k_B*T*nu**2/c**2

# %% [markdown]
# Problem 2(b)

# %%
nu = np.linspace(1e-9,1e9)
F_1 = F_nu(310.15, nu)
F_2 = F_nu(5778, nu)
plt.title("Blackbody Frequency Spectrum")
plt.plot(nu, F_1, color ="r", label="T = 310.15K")
plt.plot(nu, F_2, color ="g", label="T = 5778K")
plt.legend(loc='upper center')
plt.yscale('log')
plt.xscale('log')
plt.ylabel('$F_\\nu / Wm^{-2}Hz^{-1}$')
plt.xlabel('$\\nu / Hz$')
plt.show()

# %%
from scipy.stats import linregress
x = np.log(nu)
y = np.log(F_1)
slope, intercept, r_value, p_value, std_err = linregress(x, y)
print(slope)
x = np.log(nu)
y = np.log(F_2)
slope, intercept, r_value, p_value, std_err = linregress(x, y)
print(slope)
# Out:
# 2.0000000000000004
# 2.0000000000000004

# %% [markdown]
# The slope of the log vs log plot is 2.
# This result agrees with my prediction.

# %% [markdown]
# Problem 3

# %%
r_array=np.array(np.linspace(0,4,10))
x_matrix = np.array([np.linspace(0,10,11)*0, np.linspace(0,10,11)*0, np.linspace(0,10,11)*0, np.linspace(0,10,11)*0, np.linspace(0,10,11)*0, np.linspace(0,10,11)*0, np.linspace(0,10,11)*0, np.linspace(0,10,11)*0, np.linspace(0,10,11)*0, np.linspace(0,10,11)*0])
for i in range(0,10):
    r=r_array[i]
    x=0.5
    for n in range(1,101):
        x = r*x*(1-x)
        if n >= 90:
            x_matrix[i][n-90]=x
plt.title("$x_n$ v.s. r ($x_0$=0.5)")
plt.plot(r_array, x_matrix[:,0], '.', color ="r", label="x90", markersize=0.5)
plt.plot(r_array, x_matrix[:,1], '.', color ="g", label="x91", markersize=0.5)
plt.plot(r_array, x_matrix[:,2], '.', color ="b", label="x92", markersize=0.5)
plt.plot(r_array, x_matrix[:,3], '.', color ="c", label="x93", markersize=0.5)
plt.plot(r_array, x_matrix[:,4], '.', color ="m", label="x94", markersize=0.5)
plt.plot(r_array, x_matrix[:,5], '.', color ="y", label="x95", markersize=0.5)
plt.plot(r_array, x_matrix[:,6], '.', color ="k", label="x96", markersize=0.5)
plt.plot(r_array, x_matrix[:,7], '.', color ="orange", label="x97", markersize=0.5)
plt.plot(r_array, x_matrix[:,8], '.', color ="pink", label="x98", markersize=0.5)
plt.plot(r_array, x_matrix[:,9], '.', color ="olive", label="x99", markersize=0.5)
plt.plot(r_array, x_matrix[:,10], '.', color ="brown", label="x100", markersize=0.5)
plt.legend(loc='upper left')
plt.ylabel('$x_n$')
plt.xlabel('$r$')
plt.show()

# %%
for i in range(0,10):
    r=r_array[i]
    x=0.2
    for n in range(1,101):
        x = r*x*(1-x)
        if n >= 90:
            x_matrix[i][n-90]=x
plt.title("$x_n$ v.s. r ($x_0$=0.2)")
plt.plot(r_array, x_matrix[:,0], '.', color ="r", label="x90", markersize=0.5)
plt.plot(r_array, x_matrix[:,1], '.', color ="g", label="x91", markersize=0.5)
plt.plot(r_array, x_matrix[:,2], '.', color ="b", label="x92", markersize=0.5)
plt.plot(r_array, x_matrix[:,3], '.', color ="c", label="x93", markersize=0.5)
plt.plot(r_array, x_matrix[:,4], '.', color ="m", label="x94", markersize=0.5)
plt.plot(r_array, x_matrix[:,5], '.', color ="y", label="x95", markersize=0.5)
plt.plot(r_array, x_matrix[:,6], '.', color ="k", label="x96", markersize=0.5)
plt.plot(r_array, x_matrix[:,7], '.', color ="orange", label="x97", markersize=0.5)
plt.plot(r_array, x_matrix[:,8], '.', color ="pink", label="x98", markersize=0.5)
plt.plot(r_array, x_matrix[:,9], '.', color ="olive", label="x99", markersize=0.5)
plt.plot(r_array, x_matrix[:,10], '.', color ="brown", label="x100", markersize=0.5)
plt.legend(loc='upper left')
plt.ylabel('$x_n$')
plt.xlabel('$r$')
plt.show()

# %%
r_array=np.array(np.linspace(0,4,10))
x_matrix = np.array([np.linspace(0,10,11)*0, np.linspace(0,10,11)*0, np.linspace(0,10,11)*0, np.linspace(0,10,11)*0, np.linspace(0,10,11)*0, np.linspace(0,10,11)*0, np.linspace(0,10,11)*0, np.linspace(0,10,11)*0, np.linspace(0,10,11)*0, np.linspace(0,10,11)*0])
for i in range(0,10):
    r=r_array[i]
    x=0.5
    for n in range(1,101):
        x = r*x*(1-x)
        if n >= 90:
            x_matrix[i][n-90]=x
plt.title("$x_n$ v.s. r ($x_0$=0.5)")
plt.plot(r_array, x_matrix[:,0], '.', color ="r", label="x90", markersize=0.5)
plt.plot(r_array, x_matrix[:,1], '.', color ="g", label="x91", markersize=0.5)
plt.plot(r_array, x_matrix[:,2], '.', color ="b", label="x92", markersize=0.5)
plt.plot(r_array, x_matrix[:,3], '.', color ="c", label="x93", markersize=0.5)
plt.plot(r_array, x_matrix[:,4], '.', color ="m", label="x94", markersize=0.5)
plt.plot(r_array, x_matrix[:,5], '.', color ="y", label="x95", markersize=0.5)
plt.plot(r_array, x_matrix[:,6], '.', color ="k", label="x96", markersize=0.5)
plt.plot(r_array, x_matrix[:,7], '.', color ="orange", label="x97", markersize=0.5)
plt.plot(r_array, x_matrix[:,8], '.', color ="pink", label="x98", markersize=0.5)
plt.plot(r_array, x_matrix[:,9], '.', color ="olive", label="x99", markersize=0.5)
plt.plot(r_array, x_matrix[:,10], '.', color ="brown", label="x100", markersize=0.5)
plt.legend(loc='upper left')
plt.ylabel('$x_n$')
plt.xlabel('$r$')

plt.xlim(3.9,4.1)
plt.show()
for i in range(0,10):
    r=r_array[i]
    x=0.2
    for n in range(1,101):
        x = r*x*(1-x)
        if n >= 90:
            x_matrix[i][n-90]=x
plt.title("$x_n$ v.s. r ($x_0$=0.2)")
plt.plot(r_array, x_matrix[:,0], '.', color ="r", label="x90", markersize=0.5)
plt.plot(r_array, x_matrix[:,1], '.', color ="g", label="x91", markersize=0.5)
plt.plot(r_array, x_matrix[:,2], '.', color ="b", label="x92", markersize=0.5)
plt.plot(r_array, x_matrix[:,3], '.', color ="c", label="x93", markersize=0.5)
plt.plot(r_array, x_matrix[:,4], '.', color ="m", label="x94", markersize=0.5)
plt.plot(r_array, x_matrix[:,5], '.', color ="y", label="x95", markersize=0.5)
plt.plot(r_array, x_matrix[:,6], '.', color ="k", label="x96", markersize=0.5)
plt.plot(r_array, x_matrix[:,7], '.', color ="orange", label="x97", markersize=0.5)
plt.plot(r_array, x_matrix[:,8], '.', color ="pink", label="x98", markersize=0.5)
plt.plot(r_array, x_matrix[:,9], '.', color ="olive", label="x99", markersize=0.5)
plt.plot(r_array, x_matrix[:,10], '.', color ="brown", label="x100", markersize=0.5)
plt.legend(loc='upper left')
plt.ylabel('$x_n$')
plt.xlabel('$r$')

plt.xlim(3.9,4.1)
plt.show()

# %% [markdown]
# As the plot zoomed to r=4.0, we can see that patterns depend on the initial value.
